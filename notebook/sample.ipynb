# %%
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain_ollama import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_ollama.chat_models import ChatOllama
from langchain_core.runnables import RunnablePassthrough
from langchain.retrievers.multi_query import MultiQueryRetriever

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# Jupyter-specific imports
from IPython.display import display, Markdown

# Set environment variable for protobuf
import os
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain_community.document_loaders import UnstructuredPDFLoader
#       2 from langchain_ollama import OllamaEmbeddings
#       3 from langchain_text_splitters import RecursiveCharacterTextSplitter
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langchain_community\document_loaders\__init__.py:18
#       1 """**Document Loaders**  are classes to load Documents.
#       2
#       3 **Document Loaders** are usually used to load a lot of Documents in a single run.
#    (...)
#      15     Document, <name>TextSplitter
#      16 """
# ---> 18 from langchain_community.document_loaders.acreom import AcreomLoader
#      19 from langchain_community.document_loaders.airbyte import (
#      20     AirbyteCDKLoader,
#      21     AirbyteGongLoader,
#    (...)
#      27     AirbyteZendeskSupportLoader,
#      28 )
#      29 from langchain_community.document_loaders.airbyte_json import AirbyteJSONLoader
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langchain_community\document_loaders\acreom.py:5
#       2 from pathlib import Path
#       3 from typing import Iterator
# ----> 5 from langchain_core.documents import Document
#       7 from langchain_community.document_loaders.base import BaseLoader
#      10 class AcreomLoader(BaseLoader):
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langchain_core\documents\__init__.py:6
#       1 """**Document** module is a collection of classes that handle documents
#       2 and their transformations.
#       3
#       4 """
#       5 from langchain_core.documents.base import Document
# ----> 6 from langchain_core.documents.compressor import BaseDocumentCompressor
#       7 from langchain_core.documents.transformers import BaseDocumentTransformer
#       9 __all__ = ["Document", "BaseDocumentTransformer", "BaseDocumentCompressor"]
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langchain_core\documents\compressor.py:6
#       3 from abc import ABC, abstractmethod
#       4 from typing import Optional, Sequence
# ----> 6 from langchain_core.callbacks import Callbacks
#       7 from langchain_core.documents import Document
#       8 from langchain_core.pydantic_v1 import BaseModel
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langchain_core\callbacks\__init__.py:21
#       1 """**Callback handlers** allow listening to events in LangChain.
#       2
#       3 **Class hierarchy:**
#    (...)
#       7     BaseCallbackHandler --> <name>CallbackHandler  # Example: AimCallbackHandler
#       8 """
#       9 from langchain_core.callbacks.base import (
#      10     AsyncCallbackHandler,
#      11     BaseCallbackHandler,
#    (...)
#      19     ToolManagerMixin,
#      20 )
# ---> 21 from langchain_core.callbacks.manager import (
#      22     AsyncCallbackManager,
#      23     AsyncCallbackManagerForChainGroup,
#      24     AsyncCallbackManagerForChainRun,
#      25     AsyncCallbackManagerForLLMRun,
#      26     AsyncCallbackManagerForRetrieverRun,
#      27     AsyncCallbackManagerForToolRun,
#      28     AsyncParentRunManager,
#      29     AsyncRunManager,
#      30     BaseRunManager,
#      31     CallbackManager,
#      32     CallbackManagerForChainGroup,
#      33     CallbackManagerForChainRun,
#      34     CallbackManagerForLLMRun,
#      35     CallbackManagerForRetrieverRun,
#      36     CallbackManagerForToolRun,
#      37     ParentRunManager,
#      38     RunManager,
#      39 )
#      40 from langchain_core.callbacks.stdout import StdOutCallbackHandler
#      41 from langchain_core.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langchain_core\callbacks\manager.py:29
#      11 from typing import (
#      12     TYPE_CHECKING,
#      13     Any,
#    (...)
#      25     cast,
#      26 )
#      27 from uuid import UUID
# ---> 29 from langsmith.run_helpers import get_run_tree_context
#      30 from tenacity import RetryCallState
#      32 from langchain_core.callbacks.base import (
#      33     BaseCallbackHandler,
#      34     BaseCallbackManager,
#    (...)
#      40     ToolManagerMixin,
#      41 )
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langsmith\run_helpers.py:40
#      15 from typing import (
#      16     TYPE_CHECKING,
#      17     Any,
#    (...)
#      35     runtime_checkable,
#      36 )
#      38 from typing_extensions import ParamSpec, TypeGuard
# ---> 40 from langsmith import client as ls_client
#      41 from langsmith import run_trees, utils
#      42 from langsmith._internal import _aiter as aitertools
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langsmith\client.py:52
#      49 from urllib3.util import Retry
#      51 import langsmith
# ---> 52 from langsmith import env as ls_env
#      53 from langsmith import schemas as ls_schemas
#      54 from langsmith import utils as ls_utils
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langsmith\env\__init__.py:3
#       1 """Utilities to get information about the runtime environment."""
#       2 from langsmith.env._git import get_git_info
# ----> 3 from langsmith.env._runtime_env import (
#       4     get_docker_compose_command,
#       5     get_docker_compose_version,
#       6     get_docker_environment,
#       7     get_docker_version,
#       8     get_langchain_env_var_metadata,
#       9     get_langchain_env_vars,
#      10     get_langchain_environment,
#      11     get_release_shas,
#      12     get_runtime_and_metrics,
#      13     get_runtime_environment,
#      14     get_system_metrics,
#      15 )
#      17 __all__ = [
#      18     "get_docker_compose_command",
#      19     "get_docker_compose_version",
#    (...)
#      29     "get_git_info",
#      30 ]
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langsmith\env\_runtime_env.py:10
#       7 import subprocess
#       8 from typing import Dict, List, Optional, Union
# ---> 10 from langsmith.utils import get_docker_compose_command
#      11 from langsmith.env._git import exec_git
#      13 try:
#      14     # psutil is an optional dependency
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langsmith\utils.py:31
#      28 import requests
#      29 from urllib3.util import Retry
# ---> 31 from langsmith import schemas as ls_schemas
#      33 _LOGGER = logging.getLogger(__name__)
#      36 class LangSmithError(Exception):
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\langsmith\schemas.py:69
#      65     created_at: datetime = Field(default_factory=lambda: datetime.now(timezone.utc))
#      66     split: Optional[Union[str, List[str]]] = None
# ---> 69 class Example(ExampleBase):
#      70     """Example model."""
#      72     id: UUID
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\pydantic\main.py:286, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     284 cls.__signature__ = ClassAttribute('__signature__', generate_model_signature(cls.__init__, fields, config))
#     285 if resolve_forward_refs:
# --> 286     cls.__try_update_forward_refs__()
#     288 # preserve `__set_name__` protocol defined in https://peps.python.org/pep-0487
#     289 # for attributes not in `new_namespace` (e.g. private attributes)
#     290 for name, obj in namespace.items():
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\pydantic\main.py:808, in BaseModel.__try_update_forward_refs__(cls, **localns)
#     802 @classmethod
#     803 def __try_update_forward_refs__(cls, **localns: Any) -> None:
#     804     """
#     805     Same as update_forward_refs but will not raise exception
#     806     when forward references are not defined.
#     807     """
# --> 808     update_model_forward_refs(cls, cls.__fields__.values(), cls.__config__.json_encoders, localns, (NameError,))
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\pydantic\typing.py:554, in update_model_forward_refs(model, fields, json_encoders, localns, exc_to_suppress)
#     552 for f in fields:
#     553     try:
# --> 554         update_field_forward_refs(f, globalns=globalns, localns=localns)
#     555     except exc_to_suppress:
#     556         pass
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\pydantic\typing.py:520, in update_field_forward_refs(field, globalns, localns)
#     518 if field.type_.__class__ == ForwardRef:
#     519     prepare = True
# --> 520     field.type_ = evaluate_forwardref(field.type_, globalns, localns or None)
#     521 if field.outer_type_.__class__ == ForwardRef:
#     522     prepare = True
#
# File c:\Users\HP\Desktop\utilities\SkillCef Hackahon\.venv\Lib\site-packages\pydantic\typing.py:66, in evaluate_forwardref(type_, globalns, localns)
#      63 def evaluate_forwardref(type_: ForwardRef, globalns: Any, localns: Any) -> Any:
#      64     # Even though it is the right signature for python 3.9, mypy complains with
#      65     # `error: Too many arguments for "_evaluate" of "ForwardRef"` hence the cast...
# ---> 66     return cast(Any, type_)._evaluate(globalns, localns, set())
#
# TypeError: ForwardRef._evaluate() missing 1 required keyword-only argument: 'recursive_guard'
